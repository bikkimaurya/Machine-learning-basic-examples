# %% [markdown]
# <h1>18 June HW</h1>

# %%
import pandas as pd

# %%
df=pd.read_csv("C:\\Users\\abhishek maurya\\Desktop\\loanf.csv")

# %%
df.head(4)
# Out:
#     Interest.Rate  FICO.Score  Loan.Length  Monthly.Income  Loan.Amount
# 6           15.31         670           36         4891.67         6000
# 11          19.72         670           36         3575.00         2000
# 12          14.27         665           36         4250.00        10625
# 13          21.67         670           60        14166.67        28000

# %%
df.fillna(0)
# Out:
#       Interest.Rate  FICO.Score  Loan.Length  Monthly.Income  Loan.Amount
# 6             15.31         670           36         4891.67         6000
# 11            19.72         670           36         3575.00         2000
# 12            14.27         665           36         4250.00        10625
# 13            21.67         670           60        14166.67        28000
# 21            21.98         665           36         6666.67        22000
# 23            17.99         665           60         4100.00         6500
# 25            16.82         670           60         4500.00         4000
# 40            12.49         660           36         3448.33         2400
# 41            17.27         670           36         2500.00         3200
# 43            19.13         660           36        12000.00         5500
# 44            21.74         660           36         3700.00        15650
# 48            23.91         670           60        11250.00        20000
# ...

# %%
df["Interest.Rate"].max()
# Out:
# 24.89

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.model_selection import train_test_split

# %%
df.describe()
# Out:
#        Interest.Rate   FICO.Score  Loan.Length  Monthly.Income   Loan.Amount
# count    2500.000000  2500.000000  2500.000000     2499.000000   2500.000000
# mean       13.066996   705.888000    41.260800     5688.931321  12406.500000
# std         4.178230    35.033161     9.930893     3963.118185   7801.544872
# min         5.420000   640.000000    36.000000      588.500000   1000.000000
# 25%        10.160000   680.000000    36.000000     3500.000000   6000.000000
# 50%        13.110000   700.000000    36.000000     5000.000000  10000.000000
# 75%        15.800000   725.000000    36.000000     6800.000000  17000.000000
# max        24.890000   830.000000    60.000000   102750.000000  35000.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2500 entries, 6 to 2497
# Data columns (total 5 columns):
# Interest.Rate     2500 non-null float64
# FICO.Score        2500 non-null int64
# Loan.Length       2500 non-null int64
# Monthly.Income    2499 non-null float64
# Loan.Amount       2500 non-null int64
# dtypes: float64(2), int64(3)
# memory usage: 197.2 KB

# %%
x=df[["FICO.Score","Loan.Amount"]].values
x
# Out:
# array([[  670,  6000],
#        [  670,  2000],
#        [  665, 10625],
#        ...,
#        [  810, 27000],
#        [  765, 25000],
#        [  740, 16000]], dtype=int64)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
y=df.iloc[:,0].values
y
# Out:
# array([15.31, 19.72, 14.27, ...,  6.62, 10.75, 14.09])

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=0,test_size=0.2)

# %%
len(x_train)
# Out:
# 2000

# %%
model=LinearRegression()

# %%
#y_train=y_train.reshape(1,-1)

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
y_train
# Out:
# array([23.76, 13.06, 22.47, ..., 13.11, 13.11, 19.72])

# %%
model.predict([[665,10625]])
# Out:
# array([16.33362677])

# %%
a=int(input("ENter your FICO score"))
b=int(input("ENter your Loan  amount"))
# Out:
# ENter your FICO score665
# ENter your Loan  amount10625

# %%
print("your intest rate is {}".format(model.predict([[a,b]])))
# Out:
# your intest rate is [16.33362677]
