# %%
# pip install selenium
import time
time.sleep(5)

# %%
from selenium import webdriver
driver = webdriver.Chrome("C:\\Users\\abhishek maurya\\Desktop\\chromedriver.exe")
driver.get("https://www.facebook.com")
element = driver.find_element_by_name("email")
element.send_keys("prateek29mishra@gmail.com")
time.sleep(5)
element = driver.find_element_by_name("pass")
element.send_keys("Tecsim2018")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-3df0fe5c03ba> in <module>
# ----> 1 from selenium import webdriver
#       2 driver = webdriver.Chrome("C:\\Users\\abhishek maurya\\Desktop\\chromedriver.exe")
#       3 driver.get("https://www.facebook.com")
#       4 element = driver.find_element_by_name("email")
#       5 element.send_keys("prateek29mishra@gmail.com")
#
# ModuleNotFoundError: No module named 'selenium'

# %%
time.sleep(5)
element = driver.find_element_by_id("loginbutton")
element.click()

# %%
driver.get("https://www.facebook.com")

# %%
time.sleep(5)
profile = driver.find_element_by_xpath("//span[@class = '_1qv9']")
profile.click()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-8-0e58cc095080> in <module>
#       1 time.sleep(5)
# ----> 2 profile = driver.find_element_by_xpath("//span[@class = '_1qv9']")
#       3 profile.click()
#
# E:\installllll\Anaconda\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     392             element = driver.find_element_by_xpath('//div/td[1]')
#     393         """
# --> 394         return self.find_element(by=By.XPATH, value=xpath)
#     395
#     396     def find_elements_by_xpath(self, xpath):
#
# E:\installllll\Anaconda\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
# --> 978             'value': value})['value']
#     979
#     980     def find_elements(self, by=By.ID, value=None):
#
# E:\installllll\Anaconda\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# E:\installllll\Anaconda\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//span[@class = '_1qv9']"}
#   (Session info: chrome=75.0.3770.142)
#   (Driver info: chromedriver=2.46.628402 (536cd7adbad73a3783fdc2cab92ab2ba7ec361e1),platform=Windows NT 10.0.17134 x86_64)
