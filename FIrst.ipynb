# %% [markdown]
# <h1>Date 13 June</h1>

# %% [markdown]
# <b>Pandas</b>

# %%
import pandas as pd

# %%
ab = pd.read_csv("C:\\Users\\abhishek maurya\\Desktop\\pandas\\data sets\\nba.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-cf0e5a948d0f> in <module>
# ----> 1 ab = pd.read_csv("C:\\Users\\abhishek maurya\\Desktop\\pandas\\data sets\\nba.csv")
#
# E:\installllll\Anaconda\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
# ...

# %%
ab

# %%
ab.mean()#will print mean

# %%
ab.dropna()#jis bhi clm me NaN ho use drop krne k liye

# %%
ab.head()

# %%
ab.tail()#to print data set from tail

# %%
ab.dropna(how="all")# jb sbhi NaN honge to hi row remove hoga

# %%
ab.dropna(subset=["Salary"])#kevl vhi riw dlt hoga jisme salary kji value NaN hogi

# %%
ab.dropna(subset=["Age"])

# %%
ab.fillna(0)#replace NaN with zero

# %%
temp_ds=ab["College"].fillna("No college")

# %%
temp_ds

# %%
temp_ds=ab.fillna(0,inplace=True)

# %% [markdown]
# temp_ds

# %%
print(temp_ds)

# %%
ab["Salary"].max()

# %%
ab["Salary"].min()

# %%
#ab.sort_value(["Salary"],acsending=True)

# %%
#ab.sort_value(["Salary"],acsending=[True])

# %%
##ab.sort_values(["Salary"],acsending=True)

# %%
#ab.sort_values(["Salary"],acsending=[True])

# %%
#ab.sort_value(["Salary"],accsending=True)

# %%
#ab.sort_value(["Salary"],accsending=[True])

# %%
#ab.sort_values(["Name,"Number"])

# %%
ab.sort_values(["Name","Number"])

# %%
ab.sort_values(["Name","Number"],ascending=[True,False])
# Out:
#                     Name                    Team  Number Position   Age  \
# 457                    0                       0     0.0        0   0.0
# 152         Aaron Brooks           Chicago Bulls     0.0       PG  31.0
# 356         Aaron Gordon           Orlando Magic     0.0       PF  20.0
# 328       Aaron Harrison       Charlotte Hornets     9.0       SG  21.0
# 404        Adreian Payne  Minnesota Timberwolves    33.0       PF  25.0
# 312           Al Horford           Atlanta Hawks    15.0        C  30.0
# 330         Al Jefferson       Charlotte Hornets    25.0        C  31.0
# 428      Al-Farouq Aminu  Portland Trail Blazers     8.0       SF  25.0
# 368        Alan Anderson      Washington Wizards     6.0       SG  33.0
# 135        Alan Williams            Phoenix Suns    15.0        C  23.0
# 444           Alec Burks               Utah Jazz    10.0       SG  24.0
# 128             Alex Len            Phoenix Suns    21.0        C  22.0
# ...

# %%
ab.sort_values(["Number","Name"],ascending=[True,False])
# Out:
#                        Name                    Team  Number Position   Age  \
# 141     Willie Cauley-Stein        Sacramento Kings     0.0        C  22.0
# 329           Spencer Hawes       Charlotte Hornets     0.0       PF  28.0
# 22             Shane Larkin           Brooklyn Nets     0.0       PG  23.0
# 426       Russell Westbrook   Oklahoma City Thunder     0.0       PG  27.0
# 291         Orlando Johnson    New Orleans Pelicans     0.0       SG  27.0
# 120              Nick Young      Los Angeles Lakers     0.0       SF  31.0
# 174              Kevin Love     Cleveland Cavaliers     0.0       PF  27.0
# 347         Josh Richardson              Miami Heat     0.0       SG  22.0
# 323             Jeff Teague           Atlanta Hawks     0.0       PG  27.0
# 266          JaMychal Green       Memphis Grizzlies     0.0       PF  25.0
# 47            Isaiah Canaan      Philadelphia 76ers     0.0       PG  25.0
# ...

# %%
ab
# Out:
#                         Name                    Team  Number Position   Age  \
# 0              Avery Bradley          Boston Celtics     0.0       PG  25.0
# 1                Jae Crowder          Boston Celtics    99.0       SF  25.0
# 2               John Holland          Boston Celtics    30.0       SG  27.0
# 3                R.J. Hunter          Boston Celtics    28.0       SG  22.0
# 4              Jonas Jerebko          Boston Celtics     8.0       PF  29.0
# 5               Amir Johnson          Boston Celtics    90.0       PF  29.0
# 6              Jordan Mickey          Boston Celtics    55.0       PF  21.0
# 7               Kelly Olynyk          Boston Celtics    41.0        C  25.0
# 8               Terry Rozier          Boston Celtics    12.0       PG  22.0
# 9               Marcus Smart          Boston Celtics    36.0       PG  22.0
# 10           Jared Sullinger          Boston Celtics     7.0        C  24.0
# ...

# %%
ab.sort_values(["Team","Number"],ascending=[True,False])
# Out:
#                  Name                Team  Number Position   Age Height  \
# 457                 0                   0     0.0        0   0.0      0
# 313    Kris Humphries       Atlanta Hawks    43.0       PF  31.0    6-9
# 319        Mike Scott       Atlanta Hawks    32.0       PF  27.0    6-8
# 316      Mike Muscala       Atlanta Hawks    31.0       PF  24.0   6-11
# 314       Kyle Korver       Atlanta Hawks    26.0       SG  35.0    6-7
# 320   Thabo Sefolosha       Atlanta Hawks    25.0       SF  32.0    6-7
# 309     Kent Bazemore       Atlanta Hawks    24.0       SF  26.0    6-5
# 322    Walter Tavares       Atlanta Hawks    22.0        C  24.0    7-3
# 318   Dennis Schroder       Atlanta Hawks    17.0       PG  22.0    6-1
# 312        Al Horford       Atlanta Hawks    15.0        C  30.0   6-10
# 317   Lamar Patterson       Atlanta Hawks    13.0       SG  24.0    6-5
# 311      Kirk Hinrich       Atlanta Hawks    12.0       SG  35.0    6-4
# ...

# %%
ab["Salary"].rank()
# Out:
# 0      362.0
# 1      349.0
# 2        6.5
# 3      137.0
# 4      312.0
# 5      402.0
# 6      143.0
# 7      206.0
# 8      187.0
# 9      269.0
# 10     226.0
# 11     350.0
# 12     267.5
# 13     185.0
# 14     228.0
# 15     267.5
# 16      65.5
# 17     170.5
# 18     159.0
# 19     343.0
# 20     177.0
# 21      20.0
# 22     170.5
# 23     447.5
# 24     133.5
# 25      92.0
# 26     111.5
# 27      92.0
# 28      92.0
# 29     395.5
#        ...
# 428    369.0
# 429     53.0
# 430     92.0
# 431    351.0
# 432    243.0
# 433    338.0
# 434    316.0
# 435    253.0
# 436    295.0
# 437    225.0
# 438     44.0
# 439    164.0
# 440    239.0
# 441    229.0
# 442    308.0
# 443    230.0
# 444    381.0
# 445    278.0
# 446    402.0
# 447    144.0
# 448    427.0
# 449    160.0
# 450    197.0
# 451    111.5
# 452    209.0
# 453    218.0
# 454     76.0
# 455    244.5
# 456     92.0
# 457      6.5
# Name: Salary, Length: 458, dtype: float64

# %%
ab["Name"].rank()
# Out:
# Series([], Name: Name, dtype: float64)

# %%
ab["Salary"].rank()
# Out:
# 0      362.0
# 1      349.0
# 2        6.5
# 3      137.0
# 4      312.0
# 5      402.0
# 6      143.0
# 7      206.0
# 8      187.0
# 9      269.0
# 10     226.0
# 11     350.0
# 12     267.5
# 13     185.0
# 14     228.0
# 15     267.5
# 16      65.5
# 17     170.5
# 18     159.0
# 19     343.0
# 20     177.0
# 21      20.0
# 22     170.5
# 23     447.5
# 24     133.5
# 25      92.0
# 26     111.5
# 27      92.0
# 28      92.0
# 29     395.5
#        ...
# 428    369.0
# 429     53.0
# 430     92.0
# 431    351.0
# 432    243.0
# 433    338.0
# 434    316.0
# 435    253.0
# 436    295.0
# 437    225.0
# 438     44.0
# 439    164.0
# 440    239.0
# 441    229.0
# 442    308.0
# 443    230.0
# 444    381.0
# 445    278.0
# 446    402.0
# 447    144.0
# 448    427.0
# 449    160.0
# 450    197.0
# 451    111.5
# 452    209.0
# 453    218.0
# 454     76.0
# 455    244.5
# 456     92.0
# 457      6.5
# Name: Salary, Length: 458, dtype: float64

# %%
ab
# Out:
#                         Name                    Team  Number Position   Age  \
# 0              Avery Bradley          Boston Celtics     0.0       PG  25.0
# 1                Jae Crowder          Boston Celtics    99.0       SF  25.0
# 2               John Holland          Boston Celtics    30.0       SG  27.0
# 3                R.J. Hunter          Boston Celtics    28.0       SG  22.0
# 4              Jonas Jerebko          Boston Celtics     8.0       PF  29.0
# 5               Amir Johnson          Boston Celtics    90.0       PF  29.0
# 6              Jordan Mickey          Boston Celtics    55.0       PF  21.0
# 7               Kelly Olynyk          Boston Celtics    41.0        C  25.0
# 8               Terry Rozier          Boston Celtics    12.0       PG  22.0
# 9               Marcus Smart          Boston Celtics    36.0       PG  22.0
# 10           Jared Sullinger          Boston Celtics     7.0        C  24.0
# ...

# %%
ab["Salary"].rank()
# Out:
# 0      362.0
# 1      349.0
# 2        6.5
# 3      137.0
# 4      312.0
# 5      402.0
# 6      143.0
# 7      206.0
# 8      187.0
# 9      269.0
# 10     226.0
# 11     350.0
# 12     267.5
# 13     185.0
# 14     228.0
# 15     267.5
# 16      65.5
# 17     170.5
# 18     159.0
# 19     343.0
# 20     177.0
# 21      20.0
# 22     170.5
# 23     447.5
# 24     133.5
# 25      92.0
# 26     111.5
# 27      92.0
# 28      92.0
# 29     395.5
#        ...
# 428    369.0
# 429     53.0
# 430     92.0
# 431    351.0
# 432    243.0
# 433    338.0
# 434    316.0
# 435    253.0
# 436    295.0
# 437    225.0
# 438     44.0
# 439    164.0
# 440    239.0
# 441    229.0
# 442    308.0
# 443    230.0
# 444    381.0
# 445    278.0
# 446    402.0
# 447    144.0
# 448    427.0
# 449    160.0
# 450    197.0
# 451    111.5
# 452    209.0
# 453    218.0
# 454     76.0
# 455    244.5
# 456     92.0
# 457      6.5
# Name: Salary, Length: 458, dtype: float64

# %%
ab["Rank"]=ab["Salary"].rank()

# %%
ab
# Out:
#                         Name                    Team  Number Position   Age  \
# 0              Avery Bradley          Boston Celtics     0.0       PG  25.0
# 1                Jae Crowder          Boston Celtics    99.0       SF  25.0
# 2               John Holland          Boston Celtics    30.0       SG  27.0
# 3                R.J. Hunter          Boston Celtics    28.0       SG  22.0
# 4              Jonas Jerebko          Boston Celtics     8.0       PF  29.0
# 5               Amir Johnson          Boston Celtics    90.0       PF  29.0
# 6              Jordan Mickey          Boston Celtics    55.0       PF  21.0
# 7               Kelly Olynyk          Boston Celtics    41.0        C  25.0
# 8               Terry Rozier          Boston Celtics    12.0       PG  22.0
# 9               Marcus Smart          Boston Celtics    36.0       PG  22.0
# 10           Jared Sullinger          Boston Celtics     7.0        C  24.0
# ...

# %%
#ab["Salrary"].sort()

# %%
ab.sort_values(["Rank","Salary"],ascending=[True,True])
# Out:
#                        Name                    Team  Number Position   Age  \
# 2              John Holland          Boston Celtics    30.0       SG  27.0
# 46              Elton Brand      Philadelphia 76ers    42.0       PF  37.0
# 171           Dahntay Jones     Cleveland Cavaliers    30.0       SG  35.0
# 264           Jordan Farmar       Memphis Grizzlies     4.0       PG  29.0
# 269            Ray McCallum       Memphis Grizzlies     5.0       PG  24.0
# 270          Xavier Munford       Memphis Grizzlies    14.0       PG  24.0
# 273          Alex Stepheson       Memphis Grizzlies    35.0       PF  28.0
# 350           Briante Weber              Miami Heat    12.0       PG  23.0
# 353           Dorell Wright              Miami Heat    11.0       SF  30.0
# 397            Axel Toupane          Denver Nuggets     6.0       SG  23.0
# 409              Greg Smith  Minnesota Timberwolves     4.0       PF  25.0
# ...

# %%
#ab["Rank"].stype("int")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-b2cee3278c2a> in <module>
# ----> 1 ab["Rank"].stype("int")
#
# E:\installllll\Anaconda\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'stype'

# %%
ab["Team"]=="Utah Jazz"

# %%
ab[ab["Team"]=="Utah Jazz"]#kisi specifice data ko retrive krne k liye

# %%
ab[(ab["Team"]=="Utah Jazz") & (ab["College"]=="Butler")]

# %%
ab[(ab["Team"]=="Utah Jazz") & (ab["College"]=="Butler")& (ab["Name"]=="Shelvin Mack")]

# %%
ab[(ab["Team"]=="Utah Jazz") || (ab["College"]=="Butler") ||(ab["Name"]=="Shelvin Mack")]

# %%
ab[(ab["Team"]=="Utah Jazz") | (ab["College"]=="Butler")| (ab["Name"]=="Shelvin Mack")]

# %%
ab[(ab["Team"]=="Utah Jazz") | (ab["College"]=="Butler")| (ab["Name"]=="Shelvin Mack") | (True)]

# %%
ab

# %%
ab[(ab["Salary"]>6000) & (ab["College"]=="Butler")]

# %%
ab[(ab["Salary"]>6000) & (ab["College"]=="Butledr")]

# %%
ab[ab["College"].isin(["Butler","Kansas"])]

# %%
ab[ab["Salary"].between(25000,3000000000)]

# %%
ab[ab["Age"].between(25,30)]

# %%
ab[ab["Age"].between(25,26)]

# %%
ab["Salary"].unique()

# %%
ab["Team"].unique()

# %%
len(ab["Team"].unique())

# %%
ab["Team"].nunique()

# %%
ab["Salary"].unique()

# %%
len(ab["Salary"].unique())

# %%
ab["Salary"].nunique()

# %%
ab

# %%
len(ab["Team"].unique())

# %%
ab["Team"].nunique()

# %%
ab.loc[1:10]

# %%
ab.loc[10]

# %%
ab.loc[:10]

# %%
ab.loc[1:-10]

# %%
ab.loc[:-10]

# %%
ab.loc[12:10]

# %%
ab[1:10]

# %%
ab[1:-10]

# %%
ab[:-10]

# %%
ab

# %%
ab["Age"].plot.hist();

# %%
ab.plot.hist(x="Salary",y="Age");

# %%
ab.plot.scatter(x="Salary",y="Age",color="Red");
