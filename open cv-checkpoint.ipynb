# %% [markdown]
# <h1>20 JUne</h1>

# %%
import pandas as pd

# %%
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-a04ac9626b2f> in <module>
# ----> 1 from sklearn.datasets import fetch_opencv
#
# ImportError: cannot import name 'fetch_opencv' from 'sklearn.datasets' (E:\installllll\Anaconda\lib\site-packages\sklearn\datasets\__init__.py)
