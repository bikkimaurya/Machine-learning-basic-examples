# %%
import matplotlib.pyplot as plt

# %%
lst=[1,2,3,4,5,6,4,3,3,3,2,4,4,5,5,3,3,4,5,5,9,9,7,7]

# %%
plt.plot(lst)

# %%
plt.show(plt.plot(lst))

# %%
y=[1,3,4,5,7,7,5,4,3,3,3,3,3,5,6,7,4,4,2,2,2,2,4,6]

# %%
len(y)
# Out:
# 24

# %%
len(lst)
# Out:
# 24

# %%
len(y)
# Out:
# 24

# %%
plt.scatter(lst,y)
plt.show()

# %%
plt.xlabel("Value of x=")
plt.ylabel("Value of y=")
plt.scatter(lst,y)
plt.title("MY FIRST SCATTER PLOT")
plt.show()

# %%
import numpy as np

# %%
np.pi
# Out:
# 3.141592653589793

# %%
-np.pi
# Out:
# -3.141592653589793

# %%
x=np.linspace(-np.pi,np.pi,200)

plt.plot(np.sin(x))

# %%
plt.plot(np.cos(x))

# %%
x=np.linspace(-np.pi,np.pi,200)

plt.plot(np.tan(x))

# %%
y=np.linspace(-2*np.pi,3*np.pi,200)

plt.plot(np.sin(y))

# %%
plt.plot(np.cos(y))
plt.plot(np.sin(y))
plt.grid(True)

# %%
x=[1,3,4,2]

# %%
l=["java","python","c#","ruby"]
e=[.3,0,0,0]

# %%
plt.pie(x,labels=l,autopct="%lf%%",explode=e)
# Out:
# ([<matplotlib.patches.Wedge at 0x1a66688f400>,
# ...
#  [Text(1.3314791207879568, 0.4326237983580301, 'java'),
#   Text(-5.149471629032507e-08, 1.0999999999999988, 'python'),
#   Text(-0.8899186272232008, -0.6465638691739386, 'c#'),
#   Text(0.8899187785623721, -0.6465636608734332, 'ruby')],
#  [Text(0.8559508633636865, 0.27811529894444786, '10.000000%'),
#   Text(-2.8088027067450036e-08, 0.5999999999999993, '30.000001%'),
#   Text(-0.48541016030356404, -0.3526712013676028, '40.000001%'),
#   Text(0.4854102428522029, -0.35267108774914535, '20.000000%')])

# %%
plt.hist(lst,color="Black",align="right")
plt.xlabel("value of x")
plt.ylabel("value of y")
# Out:
# Text(0, 0.5, 'value of y')

# %%
plt.pie(x,labels=l,autopct="%lf%%",explode=e)
# Out:
# ([<matplotlib.patches.Wedge at 0x1a66696c400>,
# ...
#  [Text(1.3314791207879568, 0.4326237983580301, 'java'),
#   Text(-5.149471629032507e-08, 1.0999999999999988, 'python'),
#   Text(-0.8899186272232008, -0.6465638691739386, 'c#'),
#   Text(0.8899187785623721, -0.6465636608734332, 'ruby')],
#  [Text(0.8559508633636865, 0.27811529894444786, '10.000000%'),
#   Text(-2.8088027067450036e-08, 0.5999999999999993, '30.000001%'),
#   Text(-0.48541016030356404, -0.3526712013676028, '40.000001%'),
#   Text(0.4854102428522029, -0.35267108774914535, '20.000000%')])
