# %% [markdown]
# <h1>Date 16 June</h1>

# %% [markdown]
# <b>Multi linear regression</b>

# %%
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\abhishek maurya\\Desktop\\housing.csv")

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# 5        -122.25     37.85                52.0        919.0           213.0
# 6        -122.25     37.84                52.0       2535.0           489.0
# 7        -122.25     37.84                52.0       3104.0           687.0
# 8        -122.26     37.84                42.0       2555.0           665.0
# 9        -122.25     37.84                52.0       3549.0           707.0
# 10       -122.26     37.85                52.0       2202.0           434.0
# ...

# %%
df.plot.scatter("latitude","longitude")

# %%
df.fillna("No value")
# Out:
#        longitude  latitude  housing_median_age  total_rooms total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0            129
# 1        -122.22     37.86                21.0       7099.0           1106
# 2        -122.24     37.85                52.0       1467.0            190
# 3        -122.25     37.85                52.0       1274.0            235
# 4        -122.25     37.85                52.0       1627.0            280
# 5        -122.25     37.85                52.0        919.0            213
# 6        -122.25     37.84                52.0       2535.0            489
# 7        -122.25     37.84                52.0       3104.0            687
# 8        -122.26     37.84                42.0       2555.0            665
# 9        -122.25     37.84                52.0       3549.0            707
# 10       -122.26     37.85                52.0       2202.0            434
# ...

# %%
df[df["ocean_proximity"]=="INLAND"]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 954      -121.92     37.64                46.0       1280.0           209.0
# 957      -121.90     37.66                18.0       7397.0          1137.0
# 965      -121.88     37.68                23.0       2234.0           270.0
# 967      -121.88     37.67                16.0       4070.0           624.0
# 968      -121.88     37.67                25.0       2244.0           301.0
# 969      -121.89     37.67                20.0       2948.0           471.0
# 970      -121.89     37.67                19.0       2034.0           288.0
# 973      -121.88     37.66                29.0       2702.0           680.0
# 974      -121.87     37.66                39.0        522.0           116.0
# 975      -121.87     37.66                52.0        775.0           134.0
# 976      -121.89     37.66                 3.0       1565.0           464.0
# ...

# %%
df["ocean_proximity"]
# Out:
# 0        NEAR BAY
# 1        NEAR BAY
# 2        NEAR BAY
# 3        NEAR BAY
# 4        NEAR BAY
# 5        NEAR BAY
# 6        NEAR BAY
# 7        NEAR BAY
# 8        NEAR BAY
# 9        NEAR BAY
# 10       NEAR BAY
# 11       NEAR BAY
# 12       NEAR BAY
# 13       NEAR BAY
# 14       NEAR BAY
# 15       NEAR BAY
# 16       NEAR BAY
# 17       NEAR BAY
# 18       NEAR BAY
# 19       NEAR BAY
# 20       NEAR BAY
# 21       NEAR BAY
# 22       NEAR BAY
# 23       NEAR BAY
# 24       NEAR BAY
# 25       NEAR BAY
# 26       NEAR BAY
# 27       NEAR BAY
# 28       NEAR BAY
# 29       NEAR BAY
#            ...
# 20610      INLAND
# 20611      INLAND
# 20612      INLAND
# 20613      INLAND
# 20614      INLAND
# 20615      INLAND
# 20616      INLAND
# 20617      INLAND
# 20618      INLAND
# 20619      INLAND
# 20620      INLAND
# 20621      INLAND
# 20622      INLAND
# 20623      INLAND
# 20624      INLAND
# 20625      INLAND
# 20626      INLAND
# 20627      INLAND
# 20628      INLAND
# ...

# %%
df1 = pd.read_csv("C:\\Users\\abhishek maurya\\Desktop\\House Data.csv")

# %%
df1
# Out:
#    Area  Bedrooms  Age   Price
# 0  2600         3   20  550000
# 1  3000         4   15  565000
# 2  3200         3   18  610000
# 3  3600         3   30  595000
# 4  4000         5    8  760000

# %%
x=df1.iloc[:,:-1].values

# %%
x
# Out:
# array([[2600,    3,   20],
#        [3000,    4,   15],
#        [3200,    3,   18],
#        [3600,    3,   30],
#        [4000,    5,    8]], dtype=int64)

# %%
y=df1.iloc[:,-1].values

# %%
y
# Out:
# array([550000, 565000, 610000, 595000, 760000], dtype=int64)

# %%
from sklearn.linear_model import LinearRegression

# %%
import matplotlib.pyplot as plt

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.1,random_state=0)

# %%
xtrain
# Out:
# array([[2600,    3,   20],
#        [3000,    4,   15],
#        [3600,    3,   30],
#        [4000,    5,    8]], dtype=int64)

# %%
model=LinearRegression()

# %%
model.fit(x,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
model.coef_
# Out:
# array([   137.25, -26025.  ,  -6825.  ])

# %%
model.intercept_
# Out:
# 383724.9999999998

# %%
model.predict([[20000,4,32]])
# Out:
# array([2806225.])
